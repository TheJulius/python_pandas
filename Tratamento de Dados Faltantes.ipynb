# %% [markdown]
# # Relatorio de Analise V

# %% [markdown]
# ## Tratamento de Dados Faltantes

# %%
import pandas as pd

# %%
dados = pd.read_csv("dados/aluguel_residenciais.csv", sep = ";")

# %%
dados.isnull() #ele cria um DataFrame e marca TRUE se o dado for nulo
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False        True   True
# 2      False   False    False  False   False  False  False       False  False
# 3      False   False    False  False   False  False  False       False   True
# 4      False   False    False  False   False  False  False       False  False
# 5      False   False    False  False   False  False  False        True   True
# 6      False   False    False  False   False  False  False        True   True
# 7      False   False    False  False   False  False  False       False  False
# 8      False   False    False  False   False  False  False       False  False
# 9      False   False    False  False   False  False  False       False  False
# 10     False   False    False  False   False  False  False       False   True
# ...

# %%
dados.notnull() #ele cria um DataFrame e marca FALSE se o dado for nulo
# Out:
#        Tipo  Bairro  Quartos  Vagas  Suites  Area  Valor  Condominio   IPTU
# 0      True    True     True   True    True  True   True        True   True
# 1      True    True     True   True    True  True   True       False  False
# 2      True    True     True   True    True  True   True        True   True
# 3      True    True     True   True    True  True   True        True  False
# 4      True    True     True   True    True  True   True        True   True
# 5      True    True     True   True    True  True   True       False  False
# 6      True    True     True   True    True  True   True       False  False
# 7      True    True     True   True    True  True   True        True   True
# 8      True    True     True   True    True  True   True        True   True
# 9      True    True     True   True    True  True   True        True   True
# 10     True    True     True   True    True  True   True        True  False
# ...

# %%
dados.info() #usado para analizar quais colunas tem valores NULOS!!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21826 entries, 0 to 21825
# Data columns (total 9 columns):
# Tipo          21826 non-null object
# Bairro        21826 non-null object
# Quartos       21826 non-null int64
# Vagas         21826 non-null int64
# Suites        21826 non-null int64
# Area          21826 non-null int64
# Valor         21826 non-null float64
# Condominio    20758 non-null float64
# IPTU          15685 non-null float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.5+ MB

# %%
dados[dados["Valor"].isnull()] #ele pega todos os valores nulos da coluna "Valor"
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
dados[dados["IPTU"].isnull()] #ele pega todos os valores nulos da coluna "IPTU"
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 3             Apartamento              Higienópolis        1      0       0
# 5      Casa de Condomínio           Barra da Tijuca        5      4       5
# 6      Casa de Condomínio                     Ramos        2      2       0
# 10              Quitinete                Copacabana        1      0       0
# 12     Casa de Condomínio                   Taquara        3      1       1
# 16     Casa de Condomínio           Barra da Tijuca        4      3       2
# 17            Apartamento                    Olaria        3      1       0
# 18            Apartamento                    Tijuca        2      1       0
# 22                   Casa              Campo Grande        4      1       2
# 23            Apartamento                  Botafogo        2      1       0
# ...

# %%
dados[dados["Condominio"].isnull()] #ele pega todos os valores nulos da coluna "Condominio"
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 5      Casa de Condomínio           Barra da Tijuca        5      4       5
# 6      Casa de Condomínio                     Ramos        2      2       0
# 12     Casa de Condomínio                   Taquara        3      1       1
# 22                   Casa              Campo Grande        4      1       2
# 81           Casa de Vila                   Piedade        2      1       0
# 96                   Casa                  Maracanã        8      3       5
# 100                  Casa                   Benfica        1      0       0
# 144                  Casa            Jardim Carioca        3      2       1
# 160                  Casa       Lins de Vasconcelos        2      0       0
# 220          Casa de Vila              Oswaldo Cruz        1      0       1
# ...

# %%
#Nos sabemos pelo dados.info() que existem 9 valores na coluna "Valor" que sao NaN
#
#para retirar esses 9 valores utilizamos o dropna() e informamos a coluna que gostaria de eliminar os valores NaN

A = dados.shape[0] #mostrando a quantidade de registros antes do DROPNA()

dados.dropna(subset = ["Valor"], inplace = True) #fazendo o drop

B = dados.shape[0]

A - B #Mostrando a diferenca entre antes e depois do DROPNA() na coluna VALOR
# Out:
# 0

# %%
selecao = (dados["Tipo"] == "Apartamento") & (dados["Condominio"].isnull())

# %%
A = dados.shape[0] 

dados = dados[~selecao] #o TIO INVERTE A SELECAO (WOOOOW)

B = dados.shape[0]

A - B
# Out:
# 0

# %%
dados_2 = dados.fillna({"Condominio": 0, "IPTU": 0}) #o FILLNA() substitui todos os valores NaN pelo valor que quiser!!

# %%
dados_2
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 0               Quitinete                Copacabana        1      0       0
# 1                    Casa           Jardim Botânico        2      0       1
# 2             Apartamento                    Centro        1      0       0
# 3             Apartamento              Higienópolis        1      0       0
# 4             Apartamento                  Cachambi        2      0       0
# 5      Casa de Condomínio           Barra da Tijuca        5      4       5
# 6      Casa de Condomínio                     Ramos        2      2       0
# 7             Apartamento                    Grajaú        2      1       0
# 8             Apartamento       Lins de Vasconcelos        3      1       1
# 9             Apartamento                Copacabana        1      0       1
# 10              Quitinete                Copacabana        1      0       0
# ...

# %%
dados_2.to_csv("dados/alugueis_residenciais.csv", sep = ";", index = False)
